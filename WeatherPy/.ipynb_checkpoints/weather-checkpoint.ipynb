# %% [markdown]
# # API Challenge Homework - Weather Data
# ## UPenn Data Analytics Bootcamp - Fall 2020 Cohort
# ### February 10, 2021
# ### Jeremy Strauch

# %% [markdown]
# ## Observations from the Assignment
# #### (1) Duplications of nearest cities to randomly-generated lat,long coordinates was observed
# #### (2) Next time, I will save the nearest city information to a csv, thereby separating the need to run the code to finish the remainder of the assignment.
# #### (3) Some cities did not return weather information, so they were skipped entirely
# #### (4) Max temperature of a city is higher near the equator and decreases proportionally with distance; the relationship is strongest for the Northern Hemisphere, which might be on account of data set limitations (eg, fewer nearest cities in Southern Hemisphere)
# #### (5) No statistically significant relationship exists between city latitiude and cloudiness, wind speed or humidity for either hemisphere

# %%
import requests
import csv
import os
from datetime import datetime
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import random
from citipy import citipy
from api_keys import weather_api_key
from pprint import pprint
from scipy.stats import linregress
import matplotlib.patches as mpl_patches

# %%
lat = []
lng = []
nearest_city =[]
nearest_ctry =[]
temp_day = []
temp_night = []
temp_max = []
humidity = []
wind = []
clouds = []
time = []
data_dict = []
city_dict = []

num_cities = 0
counter = 999
hemisphere = [0 for x in range(counter)]

csvpath = os.path.join('.', 'data', 'cities_data.csv')
output = open(csvpath, 'w', newline ='')
csvwriter = csv.writer(output, quotechar=' ', quoting=csv.QUOTE_MINIMAL)
csvwriter.writerow(['City_ID','City','Country','Latitude','Longitude','Max_Temp(F)','Humidity(%)','Cloudiness','Wind_Speed(MPH)'])

while num_cities < counter:
    lat_rnd = random.uniform(-90,90)
    lng_rnd = random.uniform(-180,180)
    city = citipy.nearest_city(lat_rnd, lng_rnd)
    city_rnd = city.city_name
    city_rnd = city_rnd.replace("''","")
    ctry_rnd = city.country_code
    ctry_rnd = ctry_rnd.replace("''","")
    
    url ="http://api.openweathermap.org/data/2.5/weather?q="    

    data = requests.get(url+ city_rnd + "," + ctry_rnd + "&appid=" + weather_api_key).json()
    
    if data['cod']=='404':
        continue
    else:
        lat_new = data['coord']['lat']
        lng_new = data['coord']['lon']
        nearest_city.append(city_rnd)
        nearest_ctry.append(ctry_rnd)
        
        url = "http://api.openweathermap.org/data/2.5/onecall?lat=" + str(lat_new) + "&lon=" + str(lng_new) + "&exclude=hourly,current,minutely,alerts&units=imperial&appid=a7a1f8581953b7105f0c5ef795920a44"

        data_latlong = requests.get(url).json()
        lat.append(lat_new)
        lng.append(lng_new)
        data_dict.append(data_latlong)
    
        if lat_new >= 0:
            hemisphere[num_cities] = "Northern"
        else:
            hemisphere[num_cities] = "Southern"

        temp_day.append(data_latlong['daily'][0]['temp']['day'])
        temp_night.append(data_latlong['daily'][0]['temp']['night'])
        temp_max.append(data_latlong['daily'][0]['temp']['max'])
        humidity.append(data_latlong['daily'][0]['humidity'])
        clouds.append(data_latlong['daily'][0]['clouds'])
        wind.append(data_latlong['daily'][0]['wind_speed'])
        time_utc = int(data_latlong['daily'][0]['dt'])
        time.append(datetime.utcfromtimestamp(time_utc).strftime('%Y-%m-%d'))
        
        csvwriter = csv.writer(output, quotechar=' ', quoting=csv.QUOTE_MINIMAL)
        csvwriter.writerow([str(num_cities +1),city_rnd,ctry_rnd,lat_new,lng_new,
                            str(data_latlong['daily'][0]['temp']['max']),
                            str(data_latlong['daily'][0]['humidity']),
                            str(data_latlong['daily'][0]['clouds']),
                            str(data_latlong['daily'][0]['wind_speed'])])
        print(f'City ID: {str(num_cities)} for city {city_rnd} in {ctry_rnd} at latitude {str(round(lat_new,2))} and longitude {str(round(lng_new,2))} is being added to the list')
        num_cities += 1
# Out:
# City ID: 0 for city marawi in sd at latitude 18.48 and longitude 31.82 is being added to the list
# City ID: 1 for city butaritari in ki at latitude 3.07 and longitude 172.79 is being added to the list
# City ID: 2 for city balkanabat in tm at latitude 39.51 and longitude 54.37 is being added to the list
# City ID: 3 for city rikitea in pf at latitude -23.12 and longitude -134.97 is being added to the list
# City ID: 4 for city jamestown in sh at latitude -15.94 and longitude -5.72 is being added to the list
# City ID: 5 for city hilo in us at latitude 19.73 and longitude -155.09 is being added to the list
# City ID: 6 for city touros in br at latitude -5.2 and longitude -35.46 is being added to the list
# City ID: 7 for city hermanus in za at latitude -34.42 and longitude 19.23 is being added to the list
# City ID: 8 for city sayansk in ru at latitude 54.11 and longitude 102.16 is being added to the list
# City ID: 9 for city baruun-urt in mn at latitude 46.68 and longitude 113.28 is being added to the list
# City ID: 10 for city nouadhibou in mr at latitude 20.93 and longitude -17.03 is being added to the list
# City ID: 11 for city chuy in uy at latitude -33.7 and longitude -53.46 is being added to the list
# City ID: 12 for city pangnirtung in ca at latitude 66.15 and longitude -65.71 is being added to the list
# City ID: 13 for city homa bay in ke at latitude -0.53 and longitude 34.46 is being added to the list
# City ID: 14 for city bluff in nz at latitude -46.6 and longitude 168.33 is being added to the list
# City ID: 15 for city luanda in ao at latitude -8.84 and longitude 13.23 is being added to the list
# City ID: 16 for city longyearbyen in sj at latitude 78.22 and longitude 15.64 is being added to the list
# City ID: 17 for city ushuaia in ar at latitude -54.8 and longitude -68.3 is being added to the list
# City ID: 18 for city kaitangata in nz at latitude -46.28 and longitude 169.85 is being added to the list
# City ID: 19 for city muzhi in ru at latitude 65.37 and longitude 64.67 is being added to the list
# City ID: 20 for city albany in au at latitude -35.02 and longitude 117.89 is being added to the list
# City ID: 21 for city severo-kurilsk in ru at latitude 50.68 and longitude 156.12 is being added to the list
# City ID: 22 for city hermanus in za at latitude -34.42 and longitude 19.23 is being added to the list
# City ID: 23 for city albany in au at latitude -35.02 and longitude 117.89 is being added to the list
# City ID: 24 for city ushuaia in ar at latitude -54.8 and longitude -68.3 is being added to the list
# City ID: 25 for city presidencia roque saenz pena in ar at latitude -26.79 and longitude -60.44 is being added to the list
# City ID: 26 for city juan lacaze in uy at latitude -34.43 and longitude -57.44 is being added to the list
# City ID: 27 for city bilibino in ru at latitude 68.05 and longitude 166.44 is being added to the list
# City ID: 28 for city avarua in ck at latitude -21.21 and longitude -159.78 is being added to the list
# City ID: 29 for city faanui in pf at latitude -16.48 and longitude -151.75 is being added to the list
# City ID: 30 for city vila franca do campo in pt at latitude 37.72 and longitude -25.43 is being added to the list
# City ID: 31 for city luganville in vu at latitude -15.53 and longitude 167.17 is being added to the list
# City ID: 32 for city cape town in za at latitude -33.93 and longitude 18.42 is being added to the list
# City ID: 33 for city khash in ir at latitude 28.22 and longitude 61.22 is being added to the list
# City ID: 34 for city lloydminster in ca at latitude 53.28 and longitude -110.0 is being added to the list
# City ID: 35 for city te anau in nz at latitude -45.42 and longitude 167.72 is being added to the list
# City ID: 36 for city sayansk in ru at latitude 54.11 and longitude 102.16 is being added to the list
# City ID: 37 for city beringovskiy in ru at latitude 63.05 and longitude 179.32 is being added to the list
# City ID: 38 for city albany in au at latitude -35.02 and longitude 117.89 is being added to the list
# City ID: 39 for city yulara in au at latitude -25.24 and longitude 130.99 is being added to the list
# City ID: 40 for city rikitea in pf at latitude -23.12 and longitude -134.97 is being added to the list
# City ID: 41 for city iqaluit in ca at latitude 63.75 and longitude -68.51 is being added to the list
# City ID: 42 for city atuona in pf at latitude -9.8 and longitude -139.03 is being added to the list
# City ID: 43 for city bandarbeyla in so at latitude 9.49 and longitude 50.81 is being added to the list
# City ID: 44 for city avarua in ck at latitude -21.21 and longitude -159.78 is being added to the list
# City ID: 45 for city georgetown in sh at latitude -7.93 and longitude -14.42 is being added to the list
# City ID: 46 for city hermanus in za at latitude -34.42 and longitude 19.23 is being added to the list
# City ID: 47 for city adrar in dz at latitude 25.75 and longitude -1 is being added to the list
# City ID: 48 for city mahebourg in mu at latitude -20.41 and longitude 57.7 is being added to the list
# City ID: 49 for city winnemucca in us at latitude 40.97 and longitude -117.74 is being added to the list
# City ID: 50 for city rikitea in pf at latitude -23.12 and longitude -134.97 is being added to the list
# City ID: 51 for city gunjur in gm at latitude 13.2 and longitude -16.73 is being added to the list
# City ID: 52 for city ushuaia in ar at latitude -54.8 and longitude -68.3 is being added to the list
# City ID: 53 for city kargasok in ru at latitude 59.06 and longitude 80.86 is being added to the list
# City ID: 54 for city myanaung in mm at latitude 18.28 and longitude 95.32 is being added to the list
# City ID: 55 for city namatanai in pg at latitude -3.67 and longitude 152.43 is being added to the list
# City ID: 56 for city tiksi in ru at latitude 71.69 and longitude 128.87 is being added to the list
# City ID: 57 for city new norfolk in au at latitude -42.78 and longitude 147.06 is being added to the list
# City ID: 58 for city atuona in pf at latitude -9.8 and longitude -139.03 is being added to the list
# City ID: 59 for city hobart in au at latitude -42.88 and longitude 147.33 is being added to the list
# City ID: 60 for city ponta do sol in cv at latitude 17.2 and longitude -25.09 is being added to the list
# City ID: 61 for city caravelas in br at latitude -17.71 and longitude -39.25 is being added to the list
# City ID: 62 for city luderitz in na at latitude -26.65 and longitude 15.16 is being added to the list
# City ID: 63 for city san lorenzo in bo at latitude -17.53 and longitude -65.92 is being added to the list
# City ID: 64 for city bredasdorp in za at latitude -34.53 and longitude 20.04 is being added to the list
# City ID: 65 for city soyo in ao at latitude -6.13 and longitude 12.37 is being added to the list
# City ID: 66 for city flinders in au at latitude -34.58 and longitude 150.86 is being added to the list
# City ID: 67 for city kodiak in us at latitude 57.79 and longitude -152.41 is being added to the list
# City ID: 68 for city castanos in mx at latitude 26.78 and longitude -101.42 is being added to the list
# City ID: 69 for city punta arenas in cl at latitude -53.15 and longitude -70.92 is being added to the list
# City ID: 70 for city kapaa in us at latitude 22.08 and longitude -159.32 is being added to the list
# City ID: 71 for city pumiao in cn at latitude 22.75 and longitude 108.48 is being added to the list
# City ID: 72 for city new norfolk in au at latitude -42.78 and longitude 147.06 is being added to the list
# City ID: 73 for city cidreira in br at latitude -30.18 and longitude -50.21 is being added to the list
# City ID: 74 for city hobyo in so at latitude 5.35 and longitude 48.53 is being added to the list
# City ID: 75 for city port elizabeth in za at latitude -33.92 and longitude 25.57 is being added to the list
# City ID: 76 for city bluff in nz at latitude -46.6 and longitude 168.33 is being added to the list
# City ID: 77 for city east london in za at latitude -33.02 and longitude 27.91 is being added to the list
# City ID: 78 for city mormugao in in at latitude 15.4 and longitude 73.8 is being added to the list
# City ID: 79 for city buraydah in sa at latitude 26.33 and longitude 43.98 is being added to the list
# City ID: 80 for city mount gambier in au at latitude -37.83 and longitude 140.77 is being added to the list
# City ID: 81 for city zalantun in cn at latitude 48 and longitude 122.72 is being added to the list
# City ID: 82 for city albany in au at latitude -35.02 and longitude 117.89 is being added to the list
# City ID: 83 for city rikitea in pf at latitude -23.12 and longitude -134.97 is being added to the list
# City ID: 84 for city srednekolymsk in ru at latitude 67.45 and longitude 153.68 is being added to the list
# City ID: 85 for city vaini in to at latitude -21.2 and longitude -175.2 is being added to the list
# City ID: 86 for city rikitea in pf at latitude -23.12 and longitude -134.97 is being added to the list
# City ID: 87 for city concordia in ar at latitude -31.39 and longitude -58.02 is being added to the list
# City ID: 88 for city punta arenas in cl at latitude -53.15 and longitude -70.92 is being added to the list
# City ID: 89 for city vite in in at latitude 17.28 and longitude 74.55 is being added to the list
# City ID: 90 for city henties bay in na at latitude -22.12 and longitude 14.28 is being added to the list
# City ID: 91 for city hualmay in pe at latitude -11.1 and longitude -77.61 is being added to the list
# City ID: 92 for city salalah in om at latitude 17.02 and longitude 54.09 is being added to the list
# City ID: 93 for city san cristobal in ve at latitude 7.77 and longitude -72.22 is being added to the list
# City ID: 94 for city atuona in pf at latitude -9.8 and longitude -139.03 is being added to the list
# City ID: 95 for city east london in za at latitude -33.02 and longitude 27.91 is being added to the list
# City ID: 96 for city quirinopolis in br at latitude -18.45 and longitude -50.45 is being added to the list
# City ID: 97 for city bethel in us at latitude 41.37 and longitude -73.41 is being added to the list
# City ID: 98 for city beysehir in tr at latitude 37.68 and longitude 31.72 is being added to the list
# City ID: 99 for city busselton in au at latitude -33.65 and longitude 115.33 is being added to the list
# City ID: 100 for city busselton in au at latitude -33.65 and longitude 115.33 is being added to the list
# City ID: 101 for city tuyen quang in vn at latitude 21.82 and longitude 105.22 is being added to the list
# City ID: 102 for city cabo san lucas in mx at latitude 22.89 and longitude -109.91 is being added to the list
# City ID: 103 for city bethel in us at latitude 41.37 and longitude -73.41 is being added to the list
# City ID: 104 for city leningradskiy in ru at latitude 69.38 and longitude 178.42 is being added to the list
# City ID: 105 for city rikitea in pf at latitude -23.12 and longitude -134.97 is being added to the list
# City ID: 106 for city ushuaia in ar at latitude -54.8 and longitude -68.3 is being added to the list
# City ID: 107 for city albany in au at latitude -35.02 and longitude 117.89 is being added to the list
# City ID: 108 for city hearst in ca at latitude 49.68 and longitude -83.67 is being added to the list
# City ID: 109 for city hilo in us at latitude 19.73 and longitude -155.09 is being added to the list
# City ID: 110 for city upernavik in gl at latitude 72.79 and longitude -56.15 is being added to the list
# City ID: 111 for city tiksi in ru at latitude 71.69 and longitude 128.87 is being added to the list
# City ID: 112 for city pevek in ru at latitude 69.7 and longitude 170.31 is being added to the list
# City ID: 113 for city ushuaia in ar at latitude -54.8 and longitude -68.3 is being added to the list
# City ID: 114 for city port elizabeth in za at latitude -33.92 and longitude 25.57 is being added to the list
# City ID: 115 for city sergeyevka in kz at latitude 53.88 and longitude 67.42 is being added to the list
# City ID: 116 for city busselton in au at latitude -33.65 and longitude 115.33 is being added to the list
# City ID: 117 for city paredon in mx at latitude 16.03 and longitude -93.87 is being added to the list
# City ID: 118 for city haines junction in ca at latitude 60.75 and longitude -137.51 is being added to the list
# City ID: 119 for city gushikawa in jp at latitude 26.35 and longitude 127.87 is being added to the list
# City ID: 120 for city rikitea in pf at latitude -23.12 and longitude -134.97 is being added to the list
# City ID: 121 for city rikitea in pf at latitude -23.12 and longitude -134.97 is being added to the list
# City ID: 122 for city mar del plata in ar at latitude -38.0 and longitude -57.56 is being added to the list
# City ID: 123 for city jamestown in sh at latitude -15.94 and longitude -5.72 is being added to the list
# City ID: 124 for city omsukchan in ru at latitude 62.53 and longitude 155.8 is being added to the list
# City ID: 125 for city lethem in gy at latitude 3.38 and longitude -59.8 is being added to the list
# City ID: 126 for city kapaa in us at latitude 22.08 and longitude -159.32 is being added to the list
# City ID: 127 for city kavieng in pg at latitude -2.57 and longitude 150.8 is being added to the list
# City ID: 128 for city jamestown in sh at latitude -15.94 and longitude -5.72 is being added to the list
# City ID: 129 for city clyde river in ca at latitude 70.47 and longitude -68.59 is being added to the list
# City ID: 130 for city atuona in pf at latitude -9.8 and longitude -139.03 is being added to the list
# City ID: 131 for city valle hermoso in mx at latitude 25.67 and longitude -97.83 is being added to the list
# City ID: 132 for city port alfred in za at latitude -33.59 and longitude 26.89 is being added to the list
# City ID: 133 for city east london in za at latitude -33.02 and longitude 27.91 is being added to the list
# City ID: 134 for city dikson in ru at latitude 73.51 and longitude 80.55 is being added to the list
# City ID: 135 for city port elizabeth in za at latitude -33.92 and longitude 25.57 is being added to the list
# City ID: 136 for city ushuaia in ar at latitude -54.8 and longitude -68.3 is being added to the list
# City ID: 137 for city albany in au at latitude -35.02 and longitude 117.89 is being added to the list
# City ID: 138 for city geraldton in au at latitude -28.77 and longitude 114.6 is being added to the list
# City ID: 139 for city saldanha in za at latitude -33.01 and longitude 17.94 is being added to the list
# City ID: 140 for city yamada in jp at latitude 39.47 and longitude 141.95 is being added to the list
# City ID: 141 for city provideniya in ru at latitude 64.38 and longitude -173.3 is being added to the list
# City ID: 142 for city maceio in br at latitude -9.67 and longitude -35.74 is being added to the list
# City ID: 143 for city labuhan in id at latitude -6.88 and longitude 112.21 is being added to the list
# City ID: 144 for city sambava in mg at latitude -14.27 and longitude 50.17 is being added to the list
# City ID: 145 for city ushuaia in ar at latitude -54.8 and longitude -68.3 is being added to the list
# City ID: 146 for city bataipora in br at latitude -22.3 and longitude -53.27 is being added to the list
# City ID: 147 for city dandong in cn at latitude 40.13 and longitude 124.39 is being added to the list
# City ID: 148 for city bluff in nz at latitude -46.6 and longitude 168.33 is being added to the list
# City ID: 149 for city warri in ng at latitude 5.52 and longitude 5.75 is being added to the list
# City ID: 150 for city neiafu in to at latitude -18.65 and longitude -173.98 is being added to the list
# City ID: 151 for city rikitea in pf at latitude -23.12 and longitude -134.97 is being added to the list
# City ID: 152 for city lorengau in pg at latitude -2.02 and longitude 147.27 is being added to the list
# City ID: 153 for city grand gaube in mu at latitude -20.01 and longitude 57.66 is being added to the list
# City ID: 154 for city esperance in au at latitude -33.87 and longitude 121.9 is being added to the list
# City ID: 155 for city belokurikha in ru at latitude 52.0 and longitude 84.99 is being added to the list
# City ID: 156 for city rikitea in pf at latitude -23.12 and longitude -134.97 is being added to the list
# City ID: 157 for city ushuaia in ar at latitude -54.8 and longitude -68.3 is being added to the list
# City ID: 158 for city bluff in nz at latitude -46.6 and longitude 168.33 is being added to the list
# City ID: 159 for city upernavik in gl at latitude 72.79 and longitude -56.15 is being added to the list
# City ID: 160 for city saint-philippe in re at latitude -21.36 and longitude 55.77 is being added to the list
# City ID: 161 for city lebu in cl at latitude -37.62 and longitude -73.65 is being added to the list
# City ID: 162 for city teya in ru at latitude 60.38 and longitude 92.63 is being added to the list
# City ID: 163 for city dunedin in nz at latitude -45.87 and longitude 170.5 is being added to the list
# City ID: 164 for city kapaa in us at latitude 22.08 and longitude -159.32 is being added to the list
# City ID: 165 for city xingyi in cn at latitude 24.19 and longitude 102.82 is being added to the list
# City ID: 166 for city norman wells in ca at latitude 65.28 and longitude -126.83 is being added to the list
# City ID: 167 for city port alfred in za at latitude -33.59 and longitude 26.89 is being added to the list
# City ID: 168 for city thompson in ca at latitude 55.74 and longitude -97.86 is being added to the list
# City ID: 169 for city ribeira grande in pt at latitude 38.52 and longitude -28.7 is being added to the list
# City ID: 170 for city qaanaaq in gl at latitude 77.48 and longitude -69.36 is being added to the list
# City ID: 171 for city port elizabeth in za at latitude -33.92 and longitude 25.57 is being added to the list
# City ID: 172 for city kiunga in pg at latitude -6.12 and longitude 141.29 is being added to the list
# City ID: 173 for city atuona in pf at latitude -9.8 and longitude -139.03 is being added to the list
# City ID: 174 for city meridian in us at latitude 43.61 and longitude -116.39 is being added to the list
# City ID: 175 for city bredasdorp in za at latitude -34.53 and longitude 20.04 is being added to the list
# City ID: 176 for city mahebourg in mu at latitude -20.41 and longitude 57.7 is being added to the list
# City ID: 177 for city houston in ca at latitude 54.4 and longitude -126.67 is being added to the list
# City ID: 178 for city quatre cocos in mu at latitude -20.21 and longitude 57.76 is being added to the list
# City ID: 179 for city lebu in cl at latitude -37.62 and longitude -73.65 is being added to the list
# City ID: 180 for city lieksa in fi at latitude 63.32 and longitude 30.02 is being added to the list
# City ID: 181 for city san patricio in mx at latitude 19.22 and longitude -104.7 is being added to the list
# City ID: 182 for city rikitea in pf at latitude -23.12 and longitude -134.97 is being added to the list
# City ID: 183 for city nanortalik in gl at latitude 60.14 and longitude -45.24 is being added to the list
# City ID: 184 for city hermanus in za at latitude -34.42 and longitude 19.23 is being added to the list
# City ID: 185 for city lagunas in pe at latitude -5.23 and longitude -75.68 is being added to the list
# City ID: 186 for city castro in cl at latitude -42.47 and longitude -73.77 is being added to the list
# City ID: 187 for city upernavik in gl at latitude 72.79 and longitude -56.15 is being added to the list
# City ID: 188 for city ushuaia in ar at latitude -54.8 and longitude -68.3 is being added to the list
# City ID: 189 for city half moon bay in us at latitude 37.46 and longitude -122.43 is being added to the list
# City ID: 190 for city port lincoln in au at latitude -34.73 and longitude 135.87 is being added to the list
# City ID: 191 for city vaini in to at latitude -21.2 and longitude -175.2 is being added to the list
# City ID: 192 for city cayenne in gf at latitude 4.93 and longitude -52.33 is being added to the list
# City ID: 193 for city kununurra in au at latitude -15.77 and longitude 128.73 is being added to the list
# City ID: 194 for city rikitea in pf at latitude -23.12 and longitude -134.97 is being added to the list
# City ID: 195 for city jamestown in sh at latitude -15.94 and longitude -5.72 is being added to the list
# City ID: 196 for city punta arenas in cl at latitude -53.15 and longitude -70.92 is being added to the list
# City ID: 197 for city lucapa in ao at latitude -8.42 and longitude 20.74 is being added to the list
# City ID: 198 for city sur in om at latitude 22.57 and longitude 59.53 is being added to the list
# City ID: 199 for city saskylakh in ru at latitude 71.92 and longitude 114.08 is being added to the list
# City ID: 200 for city chernyshevskiy in ru at latitude 63.01 and longitude 112.47 is being added to the list
# City ID: 201 for city muros in es at latitude 42.78 and longitude -9.06 is being added to the list
# City ID: 202 for city cabo san lucas in mx at latitude 22.89 and longitude -109.91 is being added to the list
# City ID: 203 for city barrow in us at latitude 71.29 and longitude -156.79 is being added to the list
# City ID: 204 for city cabedelo in br at latitude -6.98 and longitude -34.83 is being added to the list
# City ID: 205 for city talnakh in ru at latitude 69.49 and longitude 88.4 is being added to the list
# City ID: 206 for city ishinomaki in jp at latitude 38.42 and longitude 141.3 is being added to the list
# City ID: 207 for city yumen in cn at latitude 40.28 and longitude 97.2 is being added to the list
# City ID: 208 for city barrow in us at latitude 71.29 and longitude -156.79 is being added to the list
# City ID: 209 for city qaanaaq in gl at latitude 77.48 and longitude -69.36 is being added to the list
# City ID: 210 for city saskylakh in ru at latitude 71.92 and longitude 114.08 is being added to the list
# City ID: 211 for city ushuaia in ar at latitude -54.8 and longitude -68.3 is being added to the list
# City ID: 212 for city howard springs in au at latitude -12.5 and longitude 131.05 is being added to the list
# City ID: 213 for city kropotkin in ru at latitude 45.44 and longitude 40.58 is being added to the list
# City ID: 214 for city narsaq in gl at latitude 60.92 and longitude -46.05 is being added to the list
# City ID: 215 for city lebu in cl at latitude -37.62 and longitude -73.65 is being added to the list
# City ID: 216 for city vaini in to at latitude -21.2 and longitude -175.2 is being added to the list
# City ID: 217 for city rikitea in pf at latitude -23.12 and longitude -134.97 is being added to the list
# City ID: 218 for city vuktyl in ru at latitude 63.86 and longitude 57.31 is being added to the list
# City ID: 219 for city thompson in ca at latitude 55.74 and longitude -97.86 is being added to the list
# City ID: 220 for city avarua in ck at latitude -21.21 and longitude -159.78 is being added to the list
# City ID: 221 for city asfi in ma at latitude 32.3 and longitude -9.24 is being added to the list
# City ID: 222 for city punta arenas in cl at latitude -53.15 and longitude -70.92 is being added to the list
# City ID: 223 for city busselton in au at latitude -33.65 and longitude 115.33 is being added to the list
# City ID: 224 for city albany in au at latitude -35.02 and longitude 117.89 is being added to the list
# City ID: 225 for city punta arenas in cl at latitude -53.15 and longitude -70.92 is being added to the list
# City ID: 226 for city huron in us at latitude 41.15 and longitude -82.55 is being added to the list
# City ID: 227 for city marsh harbour in bs at latitude 26.54 and longitude -77.06 is being added to the list
# City ID: 228 for city rikitea in pf at latitude -23.12 and longitude -134.97 is being added to the list
# City ID: 229 for city jamestown in sh at latitude -15.94 and longitude -5.72 is being added to the list
# City ID: 230 for city husavik in is at latitude 66.04 and longitude -17.34 is being added to the list
# City ID: 231 for city acapulco in mx at latitude 16.86 and longitude -99.89 is being added to the list
# City ID: 232 for city victoria in sc at latitude -4.62 and longitude 55.45 is being added to the list
# City ID: 233 for city leh in in at latitude 34.17 and longitude 77.58 is being added to the list
# City ID: 234 for city kirkwall in gb at latitude 58.98 and longitude -2.96 is being added to the list
# City ID: 235 for city rikitea in pf at latitude -23.12 and longitude -134.97 is being added to the list
# City ID: 236 for city rikitea in pf at latitude -23.12 and longitude -134.97 is being added to the list
# City ID: 237 for city qianan in cn at latitude 44.99 and longitude 124.06 is being added to the list
# City ID: 238 for city vaini in to at latitude -21.2 and longitude -175.2 is being added to the list
# City ID: 239 for city vagur in fo at latitude 61.47 and longitude -6.81 is being added to the list
# City ID: 240 for city qaanaaq in gl at latitude 77.48 and longitude -69.36 is being added to the list
# City ID: 241 for city punta arenas in cl at latitude -53.15 and longitude -70.92 is being added to the list
# City ID: 242 for city dong hoi in vn at latitude 17.48 and longitude 106.6 is being added to the list
# City ID: 243 for city avarua in ck at latitude -21.21 and longitude -159.78 is being added to the list
# City ID: 244 for city los llanos de aridane in es at latitude 28.66 and longitude -17.92 is being added to the list
# City ID: 245 for city qaanaaq in gl at latitude 77.48 and longitude -69.36 is being added to the list
# City ID: 246 for city puerto ayora in ec at latitude -0.74 and longitude -90.35 is being added to the list
# City ID: 247 for city saskylakh in ru at latitude 71.92 and longitude 114.08 is being added to the list
# City ID: 248 for city zamora in ec at latitude -4.07 and longitude -78.96 is being added to the list
# City ID: 249 for city mahebourg in mu at latitude -20.41 and longitude 57.7 is being added to the list
# City ID: 250 for city caravelas in br at latitude -17.71 and longitude -39.25 is being added to the list
# City ID: 251 for city antofagasta in cl at latitude -23.65 and longitude -70.4 is being added to the list
# City ID: 252 for city busselton in au at latitude -33.65 and longitude 115.33 is being added to the list
# City ID: 253 for city tasiilaq in gl at latitude 65.61 and longitude -37.64 is being added to the list
# City ID: 254 for city norman wells in ca at latitude 65.28 and longitude -126.83 is being added to the list
# City ID: 255 for city pangai in to at latitude -19.8 and longitude -174.35 is being added to the list
# City ID: 256 for city isangel in vu at latitude -19.55 and longitude 169.27 is being added to the list
# City ID: 257 for city bluff in nz at latitude -46.6 and longitude 168.33 is being added to the list
# City ID: 258 for city jamestown in sh at latitude -15.94 and longitude -5.72 is being added to the list
# City ID: 259 for city busselton in au at latitude -33.65 and longitude 115.33 is being added to the list
# City ID: 260 for city moissala in td at latitude 8.34 and longitude 17.77 is being added to the list
# City ID: 261 for city okato in nz at latitude -39.2 and longitude 173.88 is being added to the list
# City ID: 262 for city ancud in cl at latitude -41.87 and longitude -73.82 is being added to the list
# City ID: 263 for city castro in cl at latitude -42.47 and longitude -73.77 is being added to the list
# City ID: 264 for city rikitea in pf at latitude -23.12 and longitude -134.97 is being added to the list
# City ID: 265 for city ballina in au at latitude -28.87 and longitude 153.57 is being added to the list
# City ID: 266 for city ushuaia in ar at latitude -54.8 and longitude -68.3 is being added to the list
# City ID: 267 for city rikitea in pf at latitude -23.12 and longitude -134.97 is being added to the list
# City ID: 268 for city port elizabeth in za at latitude -33.92 and longitude 25.57 is being added to the list
# City ID: 269 for city cape town in za at latitude -33.93 and longitude 18.42 is being added to the list
# City ID: 270 for city pisco in pe at latitude -13.7 and longitude -76.22 is being added to the list
# City ID: 271 for city saint-joseph in re at latitude -21.37 and longitude 55.62 is being added to the list
# City ID: 272 for city merke in kz at latitude 42.87 and longitude 73.18 is being added to the list
# City ID: 273 for city hermanus in za at latitude -34.42 and longitude 19.23 is being added to the list
# City ID: 274 for city nisia floresta in br at latitude -6.09 and longitude -35.21 is being added to the list
# City ID: 275 for city arraial do cabo in br at latitude -22.97 and longitude -42.03 is being added to the list
# City ID: 276 for city chala in tz at latitude -7.58 and longitude 31.27 is being added to the list
# City ID: 277 for city chuy in uy at latitude -33.7 and longitude -53.46 is being added to the list
# City ID: 278 for city tuatapere in nz at latitude -46.13 and longitude 167.68 is being added to the list
# City ID: 279 for city port lincoln in au at latitude -34.73 and longitude 135.87 is being added to the list
# City ID: 280 for city ushuaia in ar at latitude -54.8 and longitude -68.3 is being added to the list
# City ID: 281 for city hobart in au at latitude -42.88 and longitude 147.33 is being added to the list
# City ID: 282 for city libreville in ga at latitude 0.39 and longitude 9.45 is being added to the list
# City ID: 283 for city port elizabeth in za at latitude -33.92 and longitude 25.57 is being added to the list
# City ID: 284 for city ushuaia in ar at latitude -54.8 and longitude -68.3 is being added to the list
# City ID: 285 for city hokitika in nz at latitude -42.72 and longitude 170.97 is being added to the list
# City ID: 286 for city ushuaia in ar at latitude -54.8 and longitude -68.3 is being added to the list
# City ID: 287 for city ushuaia in ar at latitude -54.8 and longitude -68.3 is being added to the list
# City ID: 288 for city verkhnedneprovskiy in ru at latitude 54.98 and longitude 33.35 is being added to the list
# City ID: 289 for city victoria in sc at latitude -4.62 and longitude 55.45 is being added to the list
# City ID: 290 for city nome in us at latitude 64.5 and longitude -165.41 is being added to the list
# City ID: 291 for city hobart in au at latitude -42.88 and longitude 147.33 is being added to the list
# City ID: 292 for city mandalgovi in mn at latitude 45.76 and longitude 106.27 is being added to the list
# City ID: 293 for city luanda in ao at latitude -8.84 and longitude 13.23 is being added to the list
# City ID: 294 for city atuona in pf at latitude -9.8 and longitude -139.03 is being added to the list
# City ID: 295 for city vaini in to at latitude -21.2 and longitude -175.2 is being added to the list
# City ID: 296 for city tasiilaq in gl at latitude 65.61 and longitude -37.64 is being added to the list
# City ID: 297 for city tangping in cn at latitude 22.03 and longitude 111.93 is being added to the list
# City ID: 298 for city busselton in au at latitude -33.65 and longitude 115.33 is being added to the list
# City ID: 299 for city east london in za at latitude -33.02 and longitude 27.91 is being added to the list
# City ID: 300 for city manggar in id at latitude -2.88 and longitude 108.27 is being added to the list
# City ID: 301 for city busselton in au at latitude -33.65 and longitude 115.33 is being added to the list
# City ID: 302 for city rikitea in pf at latitude -23.12 and longitude -134.97 is being added to the list
# City ID: 303 for city chapais in ca at latitude 49.78 and longitude -74.85 is being added to the list
# City ID: 304 for city havre-saint-pierre in ca at latitude 50.23 and longitude -63.6 is being added to the list
# City ID: 305 for city punta arenas in cl at latitude -53.15 and longitude -70.92 is being added to the list
# City ID: 306 for city north bend in us at latitude 43.41 and longitude -124.22 is being added to the list
# City ID: 307 for city rikitea in pf at latitude -23.12 and longitude -134.97 is being added to the list
# City ID: 308 for city buraydah in sa at latitude 26.33 and longitude 43.98 is being added to the list
# City ID: 309 for city punta arenas in cl at latitude -53.15 and longitude -70.92 is being added to the list
# City ID: 310 for city kloulklubed in pw at latitude 7.04 and longitude 134.26 is being added to the list
# City ID: 311 for city rikitea in pf at latitude -23.12 and longitude -134.97 is being added to the list
# City ID: 312 for city arman in ru at latitude 59.7 and longitude 150.17 is being added to the list
# City ID: 313 for city tuktoyaktuk in ca at latitude 69.45 and longitude -133.04 is being added to the list
# City ID: 314 for city fortuna in us at latitude 40.6 and longitude -124.16 is being added to the list
# City ID: 315 for city chimbote in pe at latitude -9.09 and longitude -78.58 is being added to the list
# City ID: 316 for city yellowknife in ca at latitude 62.46 and longitude -114.35 is being added to the list
# City ID: 317 for city victoria in sc at latitude -4.62 and longitude 55.45 is being added to the list
# City ID: 318 for city ponta do sol in cv at latitude 17.2 and longitude -25.09 is being added to the list
# City ID: 319 for city san cristobal in ec at latitude -0.9 and longitude -89.62 is being added to the list
# City ID: 320 for city ushuaia in ar at latitude -54.8 and longitude -68.3 is being added to the list
# City ID: 321 for city camacha in pt at latitude 33.08 and longitude -16.33 is being added to the list
# City ID: 322 for city albany in au at latitude -35.02 and longitude 117.89 is being added to the list
# City ID: 323 for city punta arenas in cl at latitude -53.15 and longitude -70.92 is being added to the list
# City ID: 324 for city lorengau in pg at latitude -2.02 and longitude 147.27 is being added to the list
# City ID: 325 for city hobart in au at latitude -42.88 and longitude 147.33 is being added to the list
# City ID: 326 for city okha in ru at latitude 53.57 and longitude 142.95 is being added to the list
# City ID: 327 for city nouadhibou in mr at latitude 20.93 and longitude -17.03 is being added to the list
# City ID: 328 for city dunedin in nz at latitude -45.87 and longitude 170.5 is being added to the list
# City ID: 329 for city corralillo in cu at latitude 22.98 and longitude -80.59 is being added to the list
# City ID: 330 for city gladstone in au at latitude -23.85 and longitude 151.25 is being added to the list
# City ID: 331 for city qaanaaq in gl at latitude 77.48 and longitude -69.36 is being added to the list
# City ID: 332 for city norman wells in ca at latitude 65.28 and longitude -126.83 is being added to the list
# City ID: 333 for city viedma in ar at latitude -40.81 and longitude -63.0 is being added to the list
# City ID: 334 for city mayo in ca at latitude 63.59 and longitude -135.9 is being added to the list
# City ID: 335 for city fortuna in us at latitude 40.6 and longitude -124.16 is being added to the list
# City ID: 336 for city east london in za at latitude -33.02 and longitude 27.91 is being added to the list
# City ID: 337 for city east london in za at latitude -33.02 and longitude 27.91 is being added to the list
# City ID: 338 for city harper in lr at latitude 4.38 and longitude -7.72 is being added to the list
# City ID: 339 for city bluff in nz at latitude -46.6 and longitude 168.33 is being added to the list
# City ID: 340 for city mount isa in au at latitude -20.73 and longitude 139.5 is being added to the list
# City ID: 341 for city avarua in ck at latitude -21.21 and longitude -159.78 is being added to the list
# City ID: 342 for city atuona in pf at latitude -9.8 and longitude -139.03 is being added to the list
# City ID: 343 for city venice in us at latitude 27.1 and longitude -82.45 is being added to the list
# City ID: 344 for city korla in cn at latitude 41.76 and longitude 86.15 is being added to the list
# City ID: 345 for city rikitea in pf at latitude -23.12 and longitude -134.97 is being added to the list
# City ID: 346 for city cabo san lucas in mx at latitude 22.89 and longitude -109.91 is being added to the list
# City ID: 347 for city busselton in au at latitude -33.65 and longitude 115.33 is being added to the list
# City ID: 348 for city ilulissat in gl at latitude 69.22 and longitude -51.1 is being added to the list
# City ID: 349 for city srandakan in id at latitude -7.94 and longitude 110.25 is being added to the list
# City ID: 350 for city hasaki in jp at latitude 35.73 and longitude 140.83 is being added to the list
# City ID: 351 for city kapaa in us at latitude 22.08 and longitude -159.32 is being added to the list
# City ID: 352 for city harper in lr at latitude 4.38 and longitude -7.72 is being added to the list
# City ID: 353 for city saint-augustin in ca at latitude 51.23 and longitude -58.65 is being added to the list
# City ID: 354 for city hilo in us at latitude 19.73 and longitude -155.09 is being added to the list
# City ID: 355 for city sao filipe in cv at latitude 14.9 and longitude -24.5 is being added to the list
# City ID: 356 for city cherskiy in ru at latitude 68.75 and longitude 161.3 is being added to the list
# City ID: 357 for city saint-philippe in re at latitude -21.36 and longitude 55.77 is being added to the list
# City ID: 358 for city bagan in ru at latitude 54.1 and longitude 77.66 is being added to the list
# City ID: 359 for city libertador general san martin in ar at latitude -23.81 and longitude -64.79 is being added to the list
# City ID: 360 for city negara in id at latitude -8.32 and longitude 114.6 is being added to the list
# City ID: 361 for city sabancuy in mx at latitude 18.97 and longitude -91.18 is being added to the list
# City ID: 362 for city punta arenas in cl at latitude -53.15 and longitude -70.92 is being added to the list
# City ID: 363 for city punta arenas in cl at latitude -53.15 and longitude -70.92 is being added to the list
# City ID: 364 for city lagoa in pt at latitude 39.05 and longitude -27.98 is being added to the list
# City ID: 365 for city ewa beach in us at latitude 21.32 and longitude -158.01 is being added to the list
# City ID: 366 for city jamestown in sh at latitude -15.94 and longitude -5.72 is being added to the list
# City ID: 367 for city qaanaaq in gl at latitude 77.48 and longitude -69.36 is being added to the list
# City ID: 368 for city cape town in za at latitude -33.93 and longitude 18.42 is being added to the list
# City ID: 369 for city east london in za at latitude -33.02 and longitude 27.91 is being added to the list
# City ID: 370 for city muisne in ec at latitude 0.6 and longitude -80.03 is being added to the list
# City ID: 371 for city hilo in us at latitude 19.73 and longitude -155.09 is being added to the list
# City ID: 372 for city roald in no at latitude 62.58 and longitude 6.13 is being added to the list
# City ID: 373 for city chuy in uy at latitude -33.7 and longitude -53.46 is being added to the list
# City ID: 374 for city jiaohe in cn at latitude 43.73 and longitude 127.34 is being added to the list
# City ID: 375 for city san patricio in mx at latitude 19.22 and longitude -104.7 is being added to the list
# City ID: 376 for city pimentel in pe at latitude -6.84 and longitude -79.93 is being added to the list
# City ID: 377 for city esperance in au at latitude -33.87 and longitude 121.9 is being added to the list
# City ID: 378 for city san patricio in mx at latitude 19.22 and longitude -104.7 is being added to the list
# City ID: 379 for city bambous virieux in mu at latitude -20.34 and longitude 57.76 is being added to the list
# City ID: 380 for city srednekolymsk in ru at latitude 67.45 and longitude 153.68 is being added to the list
# City ID: 381 for city vaini in to at latitude -21.2 and longitude -175.2 is being added to the list
# City ID: 382 for city namibe in ao at latitude -15.2 and longitude 12.15 is being added to the list
# City ID: 383 for city carnarvon in au at latitude -24.87 and longitude 113.63 is being added to the list
# City ID: 384 for city port alfred in za at latitude -33.59 and longitude 26.89 is being added to the list
# City ID: 385 for city hachinohe in jp at latitude 40.5 and longitude 141.5 is being added to the list
# City ID: 386 for city albany in au at latitude -35.02 and longitude 117.89 is being added to the list
# City ID: 387 for city taltal in cl at latitude -25.4 and longitude -70.48 is being added to the list
# City ID: 388 for city corinto in ni at latitude 12.48 and longitude -87.17 is being added to the list
# City ID: 389 for city cabo san lucas in mx at latitude 22.89 and longitude -109.91 is being added to the list
# City ID: 390 for city tasiilaq in gl at latitude 65.61 and longitude -37.64 is being added to the list
# City ID: 391 for city quatre cocos in mu at latitude -20.21 and longitude 57.76 is being added to the list
# City ID: 392 for city chokurdakh in ru at latitude 70.63 and longitude 147.92 is being added to the list
# City ID: 393 for city kodiak in us at latitude 57.79 and longitude -152.41 is being added to the list
# City ID: 394 for city carnarvon in au at latitude -24.87 and longitude 113.63 is being added to the list
# City ID: 395 for city chicama in pe at latitude -7.84 and longitude -79.15 is being added to the list
# City ID: 396 for city hilo in us at latitude 19.73 and longitude -155.09 is being added to the list
# City ID: 397 for city punta arenas in cl at latitude -53.15 and longitude -70.92 is being added to the list
# City ID: 398 for city leningradskiy in ru at latitude 69.38 and longitude 178.42 is being added to the list
# City ID: 399 for city albany in au at latitude -35.02 and longitude 117.89 is being added to the list
# City ID: 400 for city yellowknife in ca at latitude 62.46 and longitude -114.35 is being added to the list
# City ID: 401 for city pershotravneve in ua at latitude 51.39 and longitude 28.87 is being added to the list
# City ID: 402 for city iranshahr in ir at latitude 27.2 and longitude 60.68 is being added to the list
# City ID: 403 for city albany in au at latitude -35.02 and longitude 117.89 is being added to the list
# City ID: 404 for city mar del plata in ar at latitude -38.0 and longitude -57.56 is being added to the list
# City ID: 405 for city kapaa in us at latitude 22.08 and longitude -159.32 is being added to the list
# City ID: 406 for city talnakh in ru at latitude 69.49 and longitude 88.4 is being added to the list
# City ID: 407 for city alyangula in au at latitude -13.85 and longitude 136.42 is being added to the list
# City ID: 408 for city grindavik in is at latitude 63.84 and longitude -22.43 is being added to the list
# City ID: 409 for city jamestown in sh at latitude -15.94 and longitude -5.72 is being added to the list
# City ID: 410 for city anshun in cn at latitude 26.25 and longitude 105.93 is being added to the list
# City ID: 411 for city ushuaia in ar at latitude -54.8 and longitude -68.3 is being added to the list
# City ID: 412 for city husavik in is at latitude 66.04 and longitude -17.34 is being added to the list
# City ID: 413 for city havre-saint-pierre in ca at latitude 50.23 and longitude -63.6 is being added to the list
# City ID: 414 for city san patricio in mx at latitude 19.22 and longitude -104.7 is being added to the list
# City ID: 415 for city severo-yeniseyskiy in ru at latitude 60.37 and longitude 93.04 is being added to the list
# City ID: 416 for city rikitea in pf at latitude -23.12 and longitude -134.97 is being added to the list
# City ID: 417 for city qaanaaq in gl at latitude 77.48 and longitude -69.36 is being added to the list
# City ID: 418 for city vaini in to at latitude -21.2 and longitude -175.2 is being added to the list
# City ID: 419 for city east london in za at latitude -33.02 and longitude 27.91 is being added to the list
# City ID: 420 for city kasongo-lunda in cd at latitude -6.47 and longitude 16.82 is being added to the list
# City ID: 421 for city cayenne in gf at latitude 4.93 and longitude -52.33 is being added to the list
# City ID: 422 for city san juan in us at latitude 26.19 and longitude -98.16 is being added to the list
# City ID: 423 for city atuona in pf at latitude -9.8 and longitude -139.03 is being added to the list
# City ID: 424 for city georgetown in sh at latitude -7.93 and longitude -14.42 is being added to the list
# City ID: 425 for city ribeira grande in pt at latitude 38.52 and longitude -28.7 is being added to the list
# City ID: 426 for city mar del plata in ar at latitude -38.0 and longitude -57.56 is being added to the list
# City ID: 427 for city faanui in pf at latitude -16.48 and longitude -151.75 is being added to the list
# City ID: 428 for city noumea in nc at latitude -22.28 and longitude 166.46 is being added to the list
# City ID: 429 for city henties bay in na at latitude -22.12 and longitude 14.28 is being added to the list
# City ID: 430 for city mahebourg in mu at latitude -20.41 and longitude 57.7 is being added to the list
# City ID: 431 for city kutum in sd at latitude 14.2 and longitude 24.67 is being added to the list
# City ID: 432 for city ushuaia in ar at latitude -54.8 and longitude -68.3 is being added to the list
# City ID: 433 for city ushuaia in ar at latitude -54.8 and longitude -68.3 is being added to the list
# City ID: 434 for city oyama in jp at latitude 36.3 and longitude 139.8 is being added to the list
# City ID: 435 for city east london in za at latitude -33.02 and longitude 27.91 is being added to the list
# City ID: 436 for city ancud in cl at latitude -41.87 and longitude -73.82 is being added to the list
# City ID: 437 for city coquimbo in cl at latitude -29.95 and longitude -71.34 is being added to the list
# City ID: 438 for city port alfred in za at latitude -33.59 and longitude 26.89 is being added to the list
# City ID: 439 for city katsuura in jp at latitude 35.13 and longitude 140.3 is being added to the list
# City ID: 440 for city punta arenas in cl at latitude -53.15 and longitude -70.92 is being added to the list
# City ID: 441 for city new norfolk in au at latitude -42.78 and longitude 147.06 is being added to the list
# City ID: 442 for city mozarlandia in br at latitude -14.74 and longitude -50.57 is being added to the list
# City ID: 443 for city broken hill in au at latitude -31.95 and longitude 141.43 is being added to the list
# City ID: 444 for city kodiak in us at latitude 57.79 and longitude -152.41 is being added to the list
# City ID: 445 for city walvis bay in na at latitude -22.96 and longitude 14.51 is being added to the list
# City ID: 446 for city punta arenas in cl at latitude -53.15 and longitude -70.92 is being added to the list
# City ID: 447 for city lavrentiya in ru at latitude 65.58 and longitude -171 is being added to the list
# City ID: 448 for city iqaluit in ca at latitude 63.75 and longitude -68.51 is being added to the list
# City ID: 449 for city butaritari in ki at latitude 3.07 and longitude 172.79 is being added to the list
# City ID: 450 for city graham in us at latitude 47.05 and longitude -122.29 is being added to the list
# City ID: 451 for city thompson in ca at latitude 55.74 and longitude -97.86 is being added to the list
# City ID: 452 for city kapaa in us at latitude 22.08 and longitude -159.32 is being added to the list
# City ID: 453 for city khatanga in ru at latitude 71.97 and longitude 102.5 is being added to the list
# City ID: 454 for city jamestown in sh at latitude -15.94 and longitude -5.72 is being added to the list
# City ID: 455 for city busselton in au at latitude -33.65 and longitude 115.33 is being added to the list
# City ID: 456 for city bluff in nz at latitude -46.6 and longitude 168.33 is being added to the list
# City ID: 457 for city yueyang in cn at latitude 29.33 and longitude 113.09 is being added to the list
# City ID: 458 for city cidreira in br at latitude -30.18 and longitude -50.21 is being added to the list
# City ID: 459 for city georgetown in sh at latitude -7.93 and longitude -14.42 is being added to the list
# City ID: 460 for city ushuaia in ar at latitude -54.8 and longitude -68.3 is being added to the list
# City ID: 461 for city kodiak in us at latitude 57.79 and longitude -152.41 is being added to the list
# City ID: 462 for city rocha in uy at latitude -34.48 and longitude -54.33 is being added to the list
# City ID: 463 for city pemba in mz at latitude -12.97 and longitude 40.52 is being added to the list
# ...
# City ID: 844 for city rikitea in pf at latitude -23.12 and longitude -134.97 is being added to the list
# City ID: 845 for city necochea in ar at latitude -38.55 and longitude -58.74 is being added to the list
# City ID: 846 for city hermanus in za at latitude -34.42 and longitude 19.23 is being added to the list
# City ID: 847 for city souillac in mu at latitude -20.52 and longitude 57.52 is being added to the list
# City ID: 848 for city puerto ayora in ec at latitude -0.74 and longitude -90.35 is being added to the list
# City ID: 849 for city ballangen in no at latitude 68.34 and longitude 16.83 is being added to the list
# City ID: 850 for city sao filipe in cv at latitude 14.9 and longitude -24.5 is being added to the list
# City ID: 851 for city hamilton in bm at latitude 32.29 and longitude -64.78 is being added to the list
# City ID: 852 for city rikitea in pf at latitude -23.12 and longitude -134.97 is being added to the list
# City ID: 853 for city burnie in au at latitude -41.07 and longitude 145.92 is being added to the list
# City ID: 854 for city ahipara in nz at latitude -35.17 and longitude 173.17 is being added to the list
# City ID: 855 for city hilo in us at latitude 19.73 and longitude -155.09 is being added to the list
# City ID: 856 for city samarai in pg at latitude -10.62 and longitude 150.67 is being added to the list
# City ID: 857 for city rikitea in pf at latitude -23.12 and longitude -134.97 is being added to the list
# City ID: 858 for city ushuaia in ar at latitude -54.8 and longitude -68.3 is being added to the list
# City ID: 859 for city rikitea in pf at latitude -23.12 and longitude -134.97 is being added to the list
# City ID: 860 for city avarua in ck at latitude -21.21 and longitude -159.78 is being added to the list
# City ID: 861 for city hilo in us at latitude 19.73 and longitude -155.09 is being added to the list
# City ID: 862 for city vao in nc at latitude -22.67 and longitude 167.48 is being added to the list
# City ID: 863 for city verkhnyaya inta in ru at latitude 65.98 and longitude 60.31 is being added to the list
# City ID: 864 for city mahebourg in mu at latitude -20.41 and longitude 57.7 is being added to the list
# City ID: 865 for city jiaozuo in cn at latitude 35.24 and longitude 113.23 is being added to the list
# City ID: 866 for city nenjiang in cn at latitude 49.18 and longitude 125.22 is being added to the list
# City ID: 867 for city kondinskoye in ru at latitude 59.65 and longitude 67.41 is being added to the list
# City ID: 868 for city cap malheureux in mu at latitude -19.98 and longitude 57.61 is being added to the list
# City ID: 869 for city georgetown in sh at latitude -7.93 and longitude -14.42 is being added to the list
# City ID: 870 for city connersville in us at latitude 39.64 and longitude -85.14 is being added to the list
# City ID: 871 for city cockburn town in bs at latitude 24.03 and longitude -74.52 is being added to the list
# City ID: 872 for city punta arenas in cl at latitude -53.15 and longitude -70.92 is being added to the list
# City ID: 873 for city vaini in to at latitude -21.2 and longitude -175.2 is being added to the list
# City ID: 874 for city lesnoy in ru at latitude 57.62 and longitude 63.08 is being added to the list
# City ID: 875 for city butaritari in ki at latitude 3.07 and longitude 172.79 is being added to the list
# City ID: 876 for city pringsewu in id at latitude -5.36 and longitude 104.97 is being added to the list
# City ID: 877 for city sabzevar in ir at latitude 36.21 and longitude 57.68 is being added to the list
# City ID: 878 for city punta arenas in cl at latitude -53.15 and longitude -70.92 is being added to the list
# City ID: 879 for city port alfred in za at latitude -33.59 and longitude 26.89 is being added to the list
# City ID: 880 for city houma in us at latitude 29.6 and longitude -90.72 is being added to the list
# City ID: 881 for city balakhninskiy in ru at latitude 58.01 and longitude 114.28 is being added to the list
# City ID: 882 for city truth or consequences in us at latitude 33.13 and longitude -107.25 is being added to the list
# City ID: 883 for city otjimbingwe in na at latitude -22.35 and longitude 16.13 is being added to the list
# City ID: 884 for city zhigansk in ru at latitude 66.77 and longitude 123.37 is being added to the list
# City ID: 885 for city thompson in ca at latitude 55.74 and longitude -97.86 is being added to the list
# City ID: 886 for city kruisfontein in za at latitude -34.0 and longitude 24.73 is being added to the list
# City ID: 887 for city atuona in pf at latitude -9.8 and longitude -139.03 is being added to the list
# City ID: 888 for city kirakira in sb at latitude -10.45 and longitude 161.92 is being added to the list
# City ID: 889 for city henties bay in na at latitude -22.12 and longitude 14.28 is being added to the list
# City ID: 890 for city jamestown in sh at latitude -15.94 and longitude -5.72 is being added to the list
# City ID: 891 for city souillac in mu at latitude -20.52 and longitude 57.52 is being added to the list
# City ID: 892 for city esperance in au at latitude -33.87 and longitude 121.9 is being added to the list
# City ID: 893 for city goure in ne at latitude 13.98 and longitude 10.27 is being added to the list
# City ID: 894 for city saint-pierre in pm at latitude 46.77 and longitude -56.17 is being added to the list
# City ID: 895 for city qaqortoq in gl at latitude 60.72 and longitude -46.03 is being added to the list
# City ID: 896 for city borogontsy in ru at latitude 62.67 and longitude 131.17 is being added to the list
# City ID: 897 for city nikolskoye in ru at latitude 59.7 and longitude 30.79 is being added to the list
# City ID: 898 for city hermanus in za at latitude -34.42 and longitude 19.23 is being added to the list
# City ID: 899 for city dongli in cn at latitude 23.57 and longitude 116.82 is being added to the list
# City ID: 900 for city changji in cn at latitude 44.02 and longitude 87.32 is being added to the list
# City ID: 901 for city marsh harbour in bs at latitude 26.54 and longitude -77.06 is being added to the list
# City ID: 902 for city ushuaia in ar at latitude -54.8 and longitude -68.3 is being added to the list
# City ID: 903 for city kaiyuan in cn at latitude 23.7 and longitude 103.3 is being added to the list
# City ID: 904 for city atuona in pf at latitude -9.8 and longitude -139.03 is being added to the list
# City ID: 905 for city nata in bw at latitude -20.22 and longitude 26.18 is being added to the list
# City ID: 906 for city veraval in in at latitude 20.9 and longitude 70.37 is being added to the list
# City ID: 907 for city carauari in br at latitude -4.88 and longitude -66.9 is being added to the list
# City ID: 908 for city broken hill in au at latitude -31.95 and longitude 141.43 is being added to the list
# City ID: 909 for city bluff in nz at latitude -46.6 and longitude 168.33 is being added to the list
# City ID: 910 for city coihaique in cl at latitude -45.58 and longitude -72.07 is being added to the list
# City ID: 911 for city saint-philippe in re at latitude -21.36 and longitude 55.77 is being added to the list
# City ID: 912 for city yulara in au at latitude -25.24 and longitude 130.99 is being added to the list
# City ID: 913 for city port augusta in au at latitude -32.5 and longitude 137.77 is being added to the list
# City ID: 914 for city butaritari in ki at latitude 3.07 and longitude 172.79 is being added to the list
# City ID: 915 for city tuatapere in nz at latitude -46.13 and longitude 167.68 is being added to the list
# City ID: 916 for city yomou in gn at latitude 7.56 and longitude -9.27 is being added to the list
# City ID: 917 for city new norfolk in au at latitude -42.78 and longitude 147.06 is being added to the list
# City ID: 918 for city port hardy in ca at latitude 50.7 and longitude -127.42 is being added to the list
# City ID: 919 for city new norfolk in au at latitude -42.78 and longitude 147.06 is being added to the list
# City ID: 920 for city bud in no at latitude 62.91 and longitude 6.91 is being added to the list
# City ID: 921 for city mehamn in no at latitude 71.04 and longitude 27.85 is being added to the list
# City ID: 922 for city touros in br at latitude -5.2 and longitude -35.46 is being added to the list
# City ID: 923 for city iwanai in jp at latitude 42.97 and longitude 140.51 is being added to the list
# City ID: 924 for city miyako in jp at latitude 39.64 and longitude 141.95 is being added to the list
# City ID: 925 for city lagoa in pt at latitude 39.05 and longitude -27.98 is being added to the list
# City ID: 926 for city arraial do cabo in br at latitude -22.97 and longitude -42.03 is being added to the list
# City ID: 927 for city punta arenas in cl at latitude -53.15 and longitude -70.92 is being added to the list
# City ID: 928 for city mar del plata in ar at latitude -38.0 and longitude -57.56 is being added to the list
# City ID: 929 for city qaanaaq in gl at latitude 77.48 and longitude -69.36 is being added to the list
# City ID: 930 for city atuona in pf at latitude -9.8 and longitude -139.03 is being added to the list
# City ID: 931 for city busselton in au at latitude -33.65 and longitude 115.33 is being added to the list
# City ID: 932 for city hithadhoo in mv at latitude -0.6 and longitude 73.08 is being added to the list
# City ID: 933 for city albany in au at latitude -35.02 and longitude 117.89 is being added to the list
# City ID: 934 for city faanui in pf at latitude -16.48 and longitude -151.75 is being added to the list
# City ID: 935 for city vaini in to at latitude -21.2 and longitude -175.2 is being added to the list
# City ID: 936 for city vrangel in ru at latitude 42.73 and longitude 133.08 is being added to the list
# City ID: 937 for city new norfolk in au at latitude -42.78 and longitude 147.06 is being added to the list
# City ID: 938 for city juegang in cn at latitude 32.32 and longitude 121.19 is being added to the list
# City ID: 939 for city dale in no at latitude 60.59 and longitude 5.82 is being added to the list
# City ID: 940 for city san cristobal in ec at latitude -0.9 and longitude -89.62 is being added to the list
# City ID: 941 for city cape town in za at latitude -33.93 and longitude 18.42 is being added to the list
# City ID: 942 for city ushuaia in ar at latitude -54.8 and longitude -68.3 is being added to the list
# City ID: 943 for city albany in au at latitude -35.02 and longitude 117.89 is being added to the list
# City ID: 944 for city bosobolo in cd at latitude 4.18 and longitude 19.9 is being added to the list
# City ID: 945 for city upington in za at latitude -28.45 and longitude 21.26 is being added to the list
# City ID: 946 for city millinocket in us at latitude 45.66 and longitude -68.71 is being added to the list
# City ID: 947 for city katsuura in jp at latitude 35.13 and longitude 140.3 is being added to the list
# City ID: 948 for city nicoya in cr at latitude 10.15 and longitude -85.45 is being added to the list
# City ID: 949 for city hermanus in za at latitude -34.42 and longitude 19.23 is being added to the list
# City ID: 950 for city torbay in ca at latitude 47.67 and longitude -52.73 is being added to the list
# City ID: 951 for city grand gaube in mu at latitude -20.01 and longitude 57.66 is being added to the list
# City ID: 952 for city avarua in ck at latitude -21.21 and longitude -159.78 is being added to the list
# City ID: 953 for city aksu in kz at latitude 52.03 and longitude 76.92 is being added to the list
# City ID: 954 for city saint george in bm at latitude 32.38 and longitude -64.68 is being added to the list
# City ID: 955 for city kapaa in us at latitude 22.08 and longitude -159.32 is being added to the list
# City ID: 956 for city iaciara in br at latitude -14.1 and longitude -46.63 is being added to the list
# City ID: 957 for city bluff in nz at latitude -46.6 and longitude 168.33 is being added to the list
# City ID: 958 for city cidreira in br at latitude -30.18 and longitude -50.21 is being added to the list
# City ID: 959 for city vaini in to at latitude -21.2 and longitude -175.2 is being added to the list
# City ID: 960 for city punta arenas in cl at latitude -53.15 and longitude -70.92 is being added to the list
# City ID: 961 for city vardo in no at latitude 70.37 and longitude 31.11 is being added to the list
# City ID: 962 for city ushuaia in ar at latitude -54.8 and longitude -68.3 is being added to the list
# City ID: 963 for city riyadh in sa at latitude 24.69 and longitude 46.72 is being added to the list
# City ID: 964 for city rocha in uy at latitude -34.48 and longitude -54.33 is being added to the list
# City ID: 965 for city voh in nc at latitude -20.97 and longitude 164.7 is being added to the list
# City ID: 966 for city portland in au at latitude -38.33 and longitude 141.6 is being added to the list
# City ID: 967 for city cherskiy in ru at latitude 68.75 and longitude 161.3 is being added to the list
# City ID: 968 for city bluff in nz at latitude -46.6 and longitude 168.33 is being added to the list
# City ID: 969 for city dongsheng in cn at latitude 39.82 and longitude 109.98 is being added to the list
# City ID: 970 for city busselton in au at latitude -33.65 and longitude 115.33 is being added to the list
# City ID: 971 for city atuona in pf at latitude -9.8 and longitude -139.03 is being added to the list
# City ID: 972 for city rio gallegos in ar at latitude -51.62 and longitude -69.22 is being added to the list
# City ID: 973 for city mabaruma in gy at latitude 8.2 and longitude -59.78 is being added to the list
# City ID: 974 for city le vauclin in mq at latitude 14.55 and longitude -60.84 is being added to the list
# City ID: 975 for city bengkulu in id at latitude -3.8 and longitude 102.27 is being added to the list
# City ID: 976 for city atar in mr at latitude 20.52 and longitude -13.05 is being added to the list
# City ID: 977 for city nikolskoye in ru at latitude 59.7 and longitude 30.79 is being added to the list
# City ID: 978 for city portland in au at latitude -38.33 and longitude 141.6 is being added to the list
# City ID: 979 for city saskylakh in ru at latitude 71.92 and longitude 114.08 is being added to the list
# City ID: 980 for city mahebourg in mu at latitude -20.41 and longitude 57.7 is being added to the list
# City ID: 981 for city esperance in au at latitude -33.87 and longitude 121.9 is being added to the list
# City ID: 982 for city dikson in ru at latitude 73.51 and longitude 80.55 is being added to the list
# City ID: 983 for city hermanus in za at latitude -34.42 and longitude 19.23 is being added to the list
# City ID: 984 for city bluff in nz at latitude -46.6 and longitude 168.33 is being added to the list
# City ID: 985 for city caxito in ao at latitude -8.58 and longitude 13.66 is being added to the list
# City ID: 986 for city bethel in us at latitude 41.37 and longitude -73.41 is being added to the list
# City ID: 987 for city arraial do cabo in br at latitude -22.97 and longitude -42.03 is being added to the list
# City ID: 988 for city bredasdorp in za at latitude -34.53 and longitude 20.04 is being added to the list
# City ID: 989 for city cape town in za at latitude -33.93 and longitude 18.42 is being added to the list
# City ID: 990 for city iqaluit in ca at latitude 63.75 and longitude -68.51 is being added to the list
# City ID: 991 for city longjiang in cn at latitude 47.33 and longitude 123.18 is being added to the list
# City ID: 992 for city torbay in ca at latitude 47.67 and longitude -52.73 is being added to the list
# City ID: 993 for city kapaa in us at latitude 22.08 and longitude -159.32 is being added to the list
# City ID: 994 for city vaini in to at latitude -21.2 and longitude -175.2 is being added to the list
# City ID: 995 for city samarai in pg at latitude -10.62 and longitude 150.67 is being added to the list
# City ID: 996 for city lompoc in us at latitude 34.64 and longitude -120.46 is being added to the list
# City ID: 997 for city hobart in au at latitude -42.88 and longitude 147.33 is being added to the list
# City ID: 998 for city anadyr in ru at latitude 64.75 and longitude 177.48 is being added to the list

# %%
weather_df = pd.DataFrame(
    {'City': nearest_city,
     'Country':nearest_ctry,
     'Longitude': lng,
     'Latitude': lat,
     'Temperature Max (F)': temp_max,
     'Humidity (%)': humidity,
     'Cloudiness': clouds,
     'Wind Speed (mph)': wind,
     'Hemisphere': hemisphere
    })
weather_df.drop_duplicates(subset='City', inplace = True)

# %%
weather_df['City'].value_counts()
# Out:
# guerrero negro    1
# khash             1
# mabaruma          1
# kieta             1
# margate           1
#                  ..
# klaksvik          1
# cidreira          1
# egvekinot         1
# lokoja            1
# bondeno           1
# Name: City, Length: 436, dtype: int64

# %%
for x in range(4):
    x_values = weather_df['Latitude']
    y_values = weather_df.iloc[:,(x+4)]
    plt.scatter(x_values,y_values, marker='o', facecolors="red", edgecolors = 'black')
    plt.xlabel('Latitude')
    plt.ylabel(weather_df.columns[x+4])
    plt.title('City Latitude vs ' + weather_df.columns[x+4])
    plt.savefig("./figures/" + weather_df.columns[x+4] + "_all_data.png")
    plt.show()
    plt.close()

# %%
    filtN = weather_df['Hemisphere']=='Northern'
    filtS = weather_df['Hemisphere']=='Southern'
    
    weather_nh_df= weather_df.loc[filtN]
    weather_sh_df= weather_df.loc[filtS]
      
for x in range(4):
    
        fig, ax = plt.subplots(1,2, figsize=(10,5))
        x_values_n = weather_nh_df['Latitude']
        x_values_s = weather_sh_df['Latitude']

        y_values_n = weather_nh_df.iloc[:,(x+4)]
        y_values_s = weather_sh_df.iloc[:,(x+4)]

        ax[0].scatter(x_values_n, y_values_n, s=10, c='b', marker='+')
        ax[0].set_xlabel('Latitude')
        ax[0].set_ylabel(weather_df.columns[x+4])
        ax[0].set_title('NHemisphere Latitude ' + weather_df.columns[x+4])
        
        (slope_n, intercept_n, rvalue_n, pvalue, stderr) = linregress(x_values_n, y_values_n)
        regress_values_n = x_values_n * slope_n + intercept_n
        ax[0].plot(x_values_n,regress_values_n,"r-")
        line_eq_n = "y = " + str(round(slope_n,2)) + "x + " + str(round(intercept_n,2))
        message_n = f'r-squared is: {round(rvalue_n**2,2)}'
        
        labels_n = [line_eq_n, message_n]
        
        ax[0].plot(x_values_n,regress_values_n,"r-")
        handles_n = [mpl_patches.Rectangle((0, 0), 1, 1, fc="white", ec="white", 
                                 lw=0, alpha=0)] * 2

        ax[0].legend(handles_n, labels_n, loc='best', fontsize='small', 
          fancybox=True, framealpha=0.7, 
          handlelength=0, handletextpad=0)

        ax[1].scatter(x_values_s,  y_values_s, s=10, c='g', marker='+')
        ax[1].set_xlabel('Latitude')
        ax[1].set_ylabel(weather_df.columns[x+4])
        ax[1].set_title('SHemisphere Latitude ' + weather_df.columns[x+4])   
        
        (slope_s, intercept_s, rvalue_s, pvalue, stderr) = linregress(x_values_s, y_values_s)
        regress_values_s = x_values_s * slope_s + intercept_s
        ax[1].plot(x_values_s,regress_values_s,"r-")
        
        line_eq_s = "y = " + str(round(slope_s,2)) + "x + " + str(round(intercept_s,2))
        message_s = f'r-squared is: {round(rvalue_s**2,2)}'
        
        labels_s = [line_eq_s, message_s]
        
        ax[1].plot(x_values_s,regress_values_s,"r-")
        handles_s = [mpl_patches.Rectangle((0, 0), 1, 1, fc="white", ec="white", 
                                 lw=0, alpha=0)] * 2

        ax[1].legend(handles_s, labels_s, loc='best', fontsize='small', 
          fancybox=True, framealpha=0.7, 
          handlelength=0, handletextpad=0)
        
        plt.savefig("./figures/" + weather_df.columns[x+4] + "_byHemisphere.png")
        plt.show()
        plt.close()
